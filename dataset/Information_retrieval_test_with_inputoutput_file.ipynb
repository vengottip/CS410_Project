# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.10.0.tar.gz (107 kB)
#      ---------------------------------------- 0.0/107.6 kB ? eta -:--:--
#      -------------------------------------- 107.6/107.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (1.26.2)
# Requirement already satisfied: pandas in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (2.1.3)
# Collecting wget (from python-terrier)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (4.66.1)
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.6.1-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting matchpy (from python-terrier)
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ---------------------------------------- 0.0/69.6 kB ? eta -:--:--
#      ---------------------------------------- 69.6/69.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (1.3.2)
# Collecting deprecated (from python-terrier)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (1.11.4)
# Requirement already satisfied: requests in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (1.3.2)
# Collecting nptyping==1.4.4 (from python-terrier)
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Collecting more_itertools (from python-terrier)
#   Downloading more_itertools-10.1.0-py3-none-any.whl.metadata (33 kB)
# Collecting ir_datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from python-terrier) (3.1.2)
# Collecting statsmodels (from python-terrier)
#   Downloading statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#       --------------------------------------- 0.2/9.2 MB 5.0 MB/s eta 0:00:02
#      - -------------------------------------- 0.4/9.2 MB 6.7 MB/s eta 0:00:02
#      -- ------------------------------------- 0.6/9.2 MB 5.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.0/9.2 MB 5.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.4/9.2 MB 6.1 MB/s eta 0:00:02
#      ------ --------------------------------- 1.6/9.2 MB 5.9 MB/s eta 0:00:02
#      -------- ------------------------------- 2.0/9.2 MB 6.4 MB/s eta 0:00:02
#      --------- ------------------------------ 2.2/9.2 MB 6.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.5/9.2 MB 6.2 MB/s eta 0:00:02
#      ------------ --------------------------- 2.9/9.2 MB 6.4 MB/s eta 0:00:01
#      -------------- ------------------------- 3.3/9.2 MB 6.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.7/9.2 MB 6.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.0/9.2 MB 7.0 MB/s eta 0:00:01
#      -------------------- ------------------- 4.8/9.2 MB 7.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 5.2/9.2 MB 7.7 MB/s eta 0:00:01
#      ------------------------ --------------- 5.7/9.2 MB 7.8 MB/s eta 0:00:01
#      ------------------------- -------------- 5.9/9.2 MB 7.8 MB/s eta 0:00:01
#      --------------------------- ------------ 6.4/9.2 MB 7.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 6.8/9.2 MB 7.7 MB/s eta 0:00:01
#      ------------------------------- -------- 7.2/9.2 MB 7.9 MB/s eta 0:00:01
#      --------------------------------- ------ 7.8/9.2 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.9/9.2 MB 7.9 MB/s eta 0:00:01
#      ------------------------------------- -- 8.5/9.2 MB 8.0 MB/s eta 0:00:01
#      -------------------------------------- - 8.8/9.2 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  9.2/9.2 MB 8.2 MB/s eta 0:00:01
#      ---------------------------------------- 9.2/9.2 MB 7.8 MB/s eta 0:00:00
# Collecting ir_measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.3.tar.gz (48 kB)
#      ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#      ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dill (from python-terrier)
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting pytrec_eval_terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-win_amd64.whl.metadata (796 bytes)
# Collecting typish>=1.7.0 (from nptyping==1.4.4->python-terrier)
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ---------------------------------------- 0.0/45.1 kB ? eta -:--:--
#      ---------------------------------------- 45.1/45.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from ir_datasets>=0.3.2->python-terrier) (4.12.2)
# Collecting inscriptis>=2.2.0 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.3.2-py3-none-any.whl (41 kB)
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ---------------------------------------- 41.2/41.2 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.5.2 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from ir_datasets>=0.3.2->python-terrier) (6.0.1)
# Collecting trec-car-tools>=2.5.4 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lz4>=3.1.10 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading lz4-4.3.2-cp310-cp310-win_amd64.whl (99 kB)
#      ---------------------------------------- 0.0/99.8 kB ? eta -:--:--
#      ---------------------------------------- 99.8/99.8 kB 6.0 MB/s eta 0:00:00
# Collecting warc3-wet>=0.2.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting zlib-state>=0.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading zlib_state-0.1.6-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting ijson>=3.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.2.3-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Collecting pyautocorpus>=0.1.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading pyautocorpus-0.1.12-cp310-cp310-win_amd64.whl.metadata (1.7 kB)
# Collecting unlzw3>=0.2.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting cwl-eval>=1.0.10 (from ir_measures>=0.3.1->python-terrier)
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from requests->python-terrier) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from requests->python-terrier) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from tqdm->python-terrier) (0.4.6)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from jinja2->python-terrier) (2.1.3)
# Collecting multiset<3.0,>=2.0 (from matchpy->python-terrier)
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from scikit-learn->python-terrier) (3.2.0)
# Collecting patsy>=0.5.2 (from statsmodels->python-terrier)
#   Downloading patsy-0.5.4-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in c:\users\gvkri\onedrive\documents\tech\uiuc\cs 410 text information systems\projects\team_project\cs410_project\cs410_venv\lib\site-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Downloading ir_datasets-0.5.5-py3-none-any.whl (318 kB)
#    ---------------------------------------- 0.0/318.0 kB ? eta -:--:--
#    ---------------------------------------  317.4/318.0 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 318.0/318.0 kB 5.0 MB/s eta 0:00:00
# Downloading pyjnius-1.6.1-cp310-cp310-win_amd64.whl (222 kB)
#    ---------------------------------------- 0.0/222.6 kB ? eta -:--:--
#    --------------------------------------- 222.6/222.6 kB 14.2 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.9 kB ? eta -:--:--
#    ---------------------------------------- 56.9/56.9 kB ? eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB 6.6 MB/s eta 0:00:00
# Downloading more_itertools-10.1.0-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#    ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Downloading ijson-3.2.3-cp310-cp310-win_amd64.whl (48 kB)
#    ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#    ---------------------------------------- 48.2/48.2 kB ? eta 0:00:00
# Downloading patsy-0.5.4-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ---------------------------------------- 233.9/233.9 kB 7.2 MB/s eta 0:00:00
# Downloading pyautocorpus-0.1.12-cp310-cp310-win_amd64.whl (7.1 kB)
# Downloading zlib_state-0.1.6-cp310-cp310-win_amd64.whl (12 kB)
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, cbor
#   Building wheel for python-terrier (setup.py): started
#   Building wheel for python-terrier (setup.py): finished with status 'done'
#   Created wheel for python-terrier: filename=python_terrier-0.10.0-py3-none-any.whl size=115588 sha256=1810083a2d0862b4c2a8c046aaf96241ee18c451debc2bfd6d9e63a1e8332d9c
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\79\7c\8f\679a982895c53af35178eceda648a4bc9a9af6af5542e31a0e
#   Building wheel for ir_measures (setup.py): started
#   Building wheel for ir_measures (setup.py): finished with status 'done'
#   Created wheel for ir_measures: filename=ir_measures-0.3.3-py3-none-any.whl size=61228 sha256=da059f1bb0ccb3985acd30cb9962a9d79d3c0084aa9e60874d52ac14319f2476
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\9f\0e\22\718279f23fef1673a4c5e433881c25080a6afaa147e007183e
#   Building wheel for chest (setup.py): started
#   Building wheel for chest (setup.py): finished with status 'done'
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7671 sha256=016bb711ca2a37771f4e00a7f975c1cf0a4cffce311740a6d860371248749368
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\88\cf\99\4773b31f855f9ecedc32a0ae400f7a4a3001b37c439b6d1a73
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9698 sha256=e14b8be106432670081d22b00204b455f2cc0ce4e73bacce9c2adbd32fdf9dc0
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for cwl-eval (setup.py): started
#   Building wheel for cwl-eval (setup.py): finished with status 'done'
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38121 sha256=d5864ecb051f051f581f8381111c42f8dfa502d30f0e394aff6663bad528b682
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\3d\c1\94\94a3e5379b1aa8fb7c7f1ad1956305d5edc98ef745b6067d87
#   Building wheel for warc3-wet-clueweb09 (setup.py): started
#   Building wheel for warc3-wet-clueweb09 (setup.py): finished with status 'done'
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18943 sha256=a0bbaadfa398acc0e2506f1e941de12d0d755d6c98bd3b6988e62122f6a10b19
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\1a\d7\91\7ffb991df87e62355d945745035470ba2616aa3d83a250b5f9
#   Building wheel for cbor (setup.py): started
#   Building wheel for cbor (setup.py): finished with status 'done'
#   Created wheel for cbor: filename=cbor-1.0.0-py3-none-any.whl size=10057 sha256=dd0ba40d817bd96b7b321b06f9a355d8b5e53d713e178bc1429cd08f49bf9ccb
#   Stored in directory: c:\users\gvkri\appdata\local\pip\cache\wheels\85\df\c9\b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, pyjnius, multiset, ijson, heapdict, cbor, zlib-state, unlzw3, trec-car-tools, pytrec_eval_terrier, pyautocorpus, patsy, nptyping, more_itertools, matchpy, lz4, dill, deprecated, cwl-eval, chest, ir_measures, inscriptis, statsmodels, ir_datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.14 dill-0.3.7 heapdict-1.0.1 ijson-3.2.3 inscriptis-2.3.2 ir_datasets-0.5.5 ir_measures-0.3.3 lz4-4.3.2 matchpy-0.5.5 more_itertools-10.1.0 multiset-2.1.1 nptyping-1.4.4 patsy-0.5.4 pyautocorpus-0.1.12 pyjnius-1.6.1 python-terrier-0.10.0 pytrec_eval_terrier-0.5.6 statsmodels-0.14.0 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.6

# %%
import pyterrier as pt
if not pt.started():
    pt.init()
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to C:\Users\gvkri\.pyterrier...
# 100% [......................................................................] 104292653 / 104292653Done
# terrier-python-helper 0.0.8 jar not found, downloading to C:\Users\gvkri\.pyterrier...
# 100% [..............................................................................] 37524 / 37524Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8

# %%
import pandas as pd
import pyterrier as pt

# %%
# Sample data
# data = [
#     {"docno": "1", "text": "Meta Quest 3 is proving popular with Steam users #Meta #PCgameshardware #Steam #Valve"},
#     {"docno": "2", "text": "Send in your Hacking Issues and get Real Solution Fast I'm available 24/7 #hacking #twitterdown #facebookdown #meta #icloud The Earlier the Better!! Text me now for SIssues and get Real Solution Fast I'm available 24/7 #hacking #twitter #facebook #instagram #icloud"},
#     {"docno": "3", "text": "Fuck Farcebook #fuckmeta #metakills #meta"},
#     {"docno": "4", "text": "Working on Everyone's Cases is your skilled hacker. Send in your hacking problems for prompt, satisfactory resolutions. 24/7 access to me #hacking #twitterdown #facebookdown #meta #icloud #support #NFTs #Crypto #BUSD #USDT #SEGA"},
#     {"docno": "5", "text": "Over 16,000 Assets ranked by Market Cap, #Bitcoin already flip #tesla & #BerkshireHathaway #meta & #NVIDIA the next one"},
#     {"docno": "6", "text": "#elon_musk #whatsapp #Meta good work"},
#     {"docno": "7", "text": "Our client, renowned academic Joan Donovan, calls for investigation of @Harvard for dismantling a disinformation team to protect #Meta from research scrutiny. Big Tech is mastering the playbook of Big Tobacco and Pharma to shut down unfavorable research. whistlebloweraid.org/joan-do"},
#     {"docno": "8", "text": "UBoat VR - Quest 3 - #vr #game #meta #quest3 #uboat #fyp"},
#     {"docno": "9", "text": "#MarkZuckerberg sells first #Meta shares in 2 years after 172% surge"},
#     {"docno": "10", "text": "Send in your Hacking Issues and get Real Solution Fast I'm available 24/7 #hacking #twitterdown #facebookdown #meta #icloud #support #coinbase #robinhood #discord"},
#     {"docno": "11", "text": "33 states accuse Meta of having a big 'open secret' — millions of underage users @YahooSports #Meta #OnlineSafety #Parenting"},
#     {"docno": "12", "text": "Having these problems? 1. Withdrawal Issues 2. Frozen Funds 3. Withdrawal Password Issues 4. SuspendedAccount #stormvail #wiboy #expmarks #metaycoin #meta #bibox #Jxbit #financingy #latokenex #latoken #latokenex-coin #Linxiym #SIF #lisixu #liyibu #Litoken"},
#     {"docno": "13", "text": "The Inverse of Inverse is not Inverse. Opposite to One is None and All. #judaism #logic #ethics #politics #philosophy #mathematics #settheory #deconstruction #buddhism #phenomenology #existentialism #numbertheory #metaphysics #epistemology #meta #writing #poetry #dadaism"},
#     {"docno": "14", "text": "Then they are running a pysop with the FBI and DOJ gave a gangstalker they have working with them #genevaroadshaunwhitmore in #GA a job w #meta for aiding and abetting them with rigging a civil rights case in Colorado federal court. cc: @Potus @VP"},
#     {"docno": "15", "text": "In #Spain, the most prominent #media outlets filed a lawsuit against #Meta for €550 million"},
#     {"docno": "16", "text": "CryptoTreeMap.com Crypto market: $LUNC +27.34% $STX +27.3% $ORDI +22.07% $LUNA +19.73% $TON -92.66% $PYTH -8.41% #LUNC #STX #ORDI #LUNA #TON #PYTH #Bitcoin #Ethereum #crypto #NFT #META #web3"},
#     {"docno": "17", "text": "Monday blessings in the crypto world! Embracing the week with: #BTC breaks $42k Bitcoin (BTC) entered the top 10 largest assets, trailing just behind #Meta. #cyptonews #Websea"},
#     {"docno": "18", "text": "Send in your Hacking Issues and get Real Solution Fast I'm available 24/7 #hacking #twitterdown #facebookdown #meta #icloud"},
#     {"docno": "19", "text": "Our whitepaper is ready, you can get acquainted with the Pluto universe. #Pluto #P2EGame #meta #NFTCollection"}
#     # Add more tweets as needed
# ]

# %%
# Initialize PyTerrier
if not pt.started():
    pt.init()

# Load the CSV file
file_path = '/content/sample_data/final_dataset.csv'
df = pd.read_csv(file_path)
# Add a 'docno' column to the dataframe
df['docno'] = df.index + 1
# Reorder the columns to make 'docno' the first column
df = df[['docno'] + [col for col in df.columns if col != 'docno']]
df['docno'] = df['docno'].astype(str)
# Display the first few rows of the dataframe
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       5 # Load the CSV file
#       6 file_path = '/content/sample_data/final_dataset.csv'
# ----> 7 df = pd.read_csv(file_path)
#       8 # Add a 'docno' column to the dataframe
#       9 df['docno'] = df.index + 1
#
# File ~\OneDrive\Documents\Tech\UIUC\cs 410 Text information systems\projects\Team_Project\CS410_Project\cs410_venv\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\OneDrive\Documents\Tech\UIUC\cs 410 Text information systems\projects\Team_Project\CS410_Project\cs410_venv\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\OneDrive\Documents\Tech\UIUC\cs 410 Text information systems\projects\Team_Project\CS410_Project\cs410_venv\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\OneDrive\Documents\Tech\UIUC\cs 410 Text information systems\projects\Team_Project\CS410_Project\cs410_venv\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\OneDrive\Documents\Tech\UIUC\cs 410 Text information systems\projects\Team_Project\CS410_Project\cs410_venv\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/final_dataset.csv'

# %%
# Create an index
indexer = pt.DFIndexer("./tweet_index", overwrite=True)
index_ref = indexer.index(df['text'], df['docno'])

# Load the index
index = pt.IndexFactory.of(index_ref)

# Retrieving with a query
retriever = pt.BatchRetrieve(index, wmodel="BM25")
# retriever = pt.BatchRetrieve(index, wmodel="DirichletLM")
results = retriever.transform(["meta stock"])

# %%
# Get top 10 results
top_10 = results.head(10)

# %%
top_10
# Out:
#   qid  docid  docno  rank      score       query
# 0   1   7005   7006     0  15.545075  meta stock
# 1   1   2204   2205     1  13.265972  meta stock
# 2   1   9737   9738     2  13.096376  meta stock
# 3   1  12913  12914     3  12.656480  meta stock
# 4   1   9761   9762     4  12.575033  meta stock
# 5   1  21182  21183     5  12.280680  meta stock
# 6   1  11339  11340     6  11.999791  meta stock
# 7   1  13085  13086     7  11.999791  meta stock
# 8   1   2205   2206     8  11.731465  meta stock
# 9   1  14014  14015     9  11.330091  meta stock

# %%
# retrieve the full text for each docno in the top_10 results
# We will add a new 'full_text' column to the top_10 DataFrame
top_10_df = pd.DataFrame(top_10)

# %%
# Assuming 'top_10' is a list or some iterable of search results
print(top_10)

top_10_df = pd.DataFrame(top_10)
print(top_10_df)  # This will print the entire DataFrame

# Print the columns again to see what we have
print(top_10_df.columns)
# Out:
#   qid  docid  docno  rank      score       query
# 0   1   7005   7006     0  15.545075  meta stock
# 1   1   2204   2205     1  13.265972  meta stock
# 2   1   9737   9738     2  13.096376  meta stock
# 3   1  12913  12914     3  12.656480  meta stock
# 4   1   9761   9762     4  12.575033  meta stock
# 5   1  21182  21183     5  12.280680  meta stock
# 6   1  11339  11340     6  11.999791  meta stock
# 7   1  13085  13086     7  11.999791  meta stock
# 8   1   2205   2206     8  11.731465  meta stock
# 9   1  14014  14015     9  11.330091  meta stock
#   qid  docid  docno  rank      score       query
# 0   1   7005   7006     0  15.545075  meta stock
# 1   1   2204   2205     1  13.265972  meta stock
# 2   1   9737   9738     2  13.096376  meta stock
# 3   1  12913  12914     3  12.656480  meta stock
# 4   1   9761   9762     4  12.575033  meta stock
# 5   1  21182  21183     5  12.280680  meta stock
# 6   1  11339  11340     6  11.999791  meta stock
# 7   1  13085  13086     7  11.999791  meta stock
# 8   1   2205   2206     8  11.731465  meta stock
# 9   1  14014  14015     9  11.330091  meta stock
# Index(['qid', 'docid', 'docno', 'rank', 'score', 'query'], dtype='object')

# %%
top_10_df = pd.DataFrame(top_10)
top_10_df['full_text'] = top_10_df['docno'].apply(lambda x: df[df['docno'] == str(x)]['text'].iloc[0])

# top_10_df contains the full text of each tweet alongside the original search result data
print(top_10_df[['docno', 'full_text', 'rank', 'query']])
# Out:
#    docno                                          full_text  rank       query
# 0   7006  My new META 1 smartwatch! #meta1 #meta #smartw...     0  meta stock
# 1   2205  Wow! Major tech players making big moves. Insi...     1  meta stock
# 2   9738  Wow, major tech shake-up happening!  Insiders ...     2  meta stock
# 3  12914  #Stocks to watch for swings today:  1.   #Ford...     3  meta stock
# 4   9762  #MarkZuckerberg is selling #Meta Platforms Inc...     4  meta stock
# 5  21183  The Nasdaq is up 47% this year.. driven by the...     5  meta stock
# 6  11340  Stocks That Have Made 52-week Highs This Week ...     6  meta stock
# 7  13086  Economic calendar & notable earnings for the w...     7  meta stock
# 8   2206  Wow, major shakeup in the tech world!  #Nvidia...     8  meta stock
# 9  14015  Here's what stocks hit the Delta Trending   #M...     9  meta stock

# %%
output_csv_file = '/content/sample_data/IF_output.csv'

# Export the DataFrame to a CSV file
top_10_df.to_csv(output_csv_file, index=False)
